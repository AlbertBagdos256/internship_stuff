# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
encounters = pd.read_csv("../data/encounters.csv")
payers = pd.read_csv("../data/payers.csv")
patients = pd.read_csv("../data/patients.csv")
claims = pd.read_csv("../data/claims.csv")

# %%
encounters.head(3)
# Out:
#                                      Id                 START  \
# 0  748f8357-6cc7-551d-f31a-32fa2cf84126  2019-02-17T05:07:38Z
# 1  5a4735ae-423f-6563-28ab-b3d11b49b2d4  2019-03-24T05:07:38Z
# 2  0bee1ce6-3e2c-5506-f71c-a7ba8f64a3d3  2019-05-26T05:07:38Z
#
#                    STOP                               PATIENT  \
# 0  2019-02-17T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 1  2019-03-24T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 2  2019-05-26T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
#
#                            ORGANIZATION                              PROVIDER  \
# 0  f7ae497d-8dc6-3721-9402-43b621a4e7d2  82608ebb-037c-3cef-9d34-3736d69b29e8
# 1  f7ae497d-8dc6-3721-9402-43b621a4e7d2  82608ebb-037c-3cef-9d34-3736d69b29e8
# 2  f7ae497d-8dc6-3721-9402-43b621a4e7d2  82608ebb-037c-3cef-9d34-3736d69b29e8
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a       wellness  410620009
# ...

# %%
encounters
# Out:
#                                          Id                 START  \
# 0      748f8357-6cc7-551d-f31a-32fa2cf84126  2019-02-17T05:07:38Z
# 1      5a4735ae-423f-6563-28ab-b3d11b49b2d4  2019-03-24T05:07:38Z
# 2      0bee1ce6-3e2c-5506-f71c-a7ba8f64a3d3  2019-05-26T05:07:38Z
# 3      6e93bcf9-45a4-8528-0120-1c1eaa930faf  2019-07-28T05:07:38Z
# 4      8b6787c3-4316-a0cb-899d-4746525c319f  2019-10-27T05:07:38Z
# ...                                     ...                   ...
# 61454  230e2215-38ab-9371-842d-a44d27ae4090  2020-12-18T05:11:58Z
# 61455  db101ad8-66e2-9feb-e0cf-b2618f873c3a  2020-12-28T02:11:58Z
# 61456  1516d2e6-4846-5f1e-fe27-c1ebb9a39f72  2021-01-15T05:11:58Z
# 61457  b2a4d90b-a2f5-1c88-0fb6-ba49b1487d37  2021-08-13T05:11:58Z
# 61458  0732798b-fb31-183b-22b6-efb205ee6502  2021-09-03T05:11:58Z
#
#                        STOP                               PATIENT  \
# 0      2019-02-17T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# ...

# %%
payers.head(2)
# Out:
#                                      Id           NAME             ADDRESS  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed  Dual Eligible  7500 Security Blvd
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c       Medicare  7500 Security Blvd
#
#         CITY STATE_HEADQUARTERED      ZIP           PHONE  AMOUNT_COVERED  \
# 0  Baltimore                  MD  21244.0  1-877-267-2323      2786029.66
# 1  Baltimore                  MD  21244.0  1-800-633-4227     36196594.58
#
#    AMOUNT_UNCOVERED    REVENUE  ...  UNCOVERED_ENCOUNTERS  \
# 0         358233.14  1439000.0  ...                     0
# 1        2549080.77  7513750.0  ...                     0
#
#    COVERED_MEDICATIONS  UNCOVERED_MEDICATIONS  COVERED_PROCEDURES  \
# 0                 1141                      0                 551
# 1                10455                      0                6957
#
#    UNCOVERED_PROCEDURES  COVERED_IMMUNIZATIONS  UNCOVERED_IMMUNIZATIONS  \
# ...

# %%
patients.head(3)
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85  2019-02-17       NaN  999-65-3251
# 1  c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN  999-49-3323
# 2  339144f8-50e1-633e-a013-f361391c4cff  1998-05-11       NaN  999-10-8743
#
#      DRIVERS    PASSPORT PREFIX     FIRST            LAST SUFFIX MAIDEN  \
# 0        NaN         NaN    NaN  Damon455      Langosh790    NaN    NaN
# 1  S99941126         NaN    NaN     Thi53       Wunsch504    NaN    NaN
# 2  S99996708  X75063318X    Mr.    Chi716  Greenfelder433    NaN    NaN
#
#   MARITAL   RACE    ETHNICITY GENDER                        BIRTHPLACE  \
# 0     NaN  white  nonhispanic      M  Middleborough  Massachusetts  US
# 1     NaN  white  nonhispanic      F        Danvers  Massachusetts  US
# 2     NaN  white  nonhispanic      M     Athens  Athens Prefecture  GR
#
#                             ADDRESS         CITY          STATE  \
# ...

# %%
patients["DEATHDATE"] = patients["DEATHDATE"].fillna("unknown")
patients["PASSPORT"] = patients["PASSPORT"].fillna("unknown")
patients["PASSPORT"] = patients["PASSPORT"].fillna("unknown")

# %%
patients["FIRST"] = patients["FIRST"].str.replace(r"\d+", "", regex=True)
# Out:
# 0         Damon
# 1           Thi
# 2           Chi
# 3       Phillis
# 4       Jerrold
#          ...
# 1158        Coy
# 1159     Sherry
# 1160      Vance
# 1161       Cody
# 1162    Haywood
# Name: FIRST, Length: 1163, dtype: object

# %%
claims.head(3)
# Out:
#                                      Id                             PATIENTID  \
# 0  e413105d-6f23-34ef-724a-b42adab9df22  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 1  8e430d76-6628-c3ac-8950-2acabeb34f86  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 2  3a69d5f0-26d8-fe66-4a1b-1a7c9ab618c8  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
#
#                              PROVIDERID             PRIMARYPATIENTINSURANCEID  \
# 0  82608ebb-037c-3cef-9d34-3736d69b29e8  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a
# 1  82608ebb-037c-3cef-9d34-3736d69b29e8  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a
# 2  82608ebb-037c-3cef-9d34-3736d69b29e8  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a
#
#   SECONDARYPATIENTINSURANCEID  DEPARTMENTID  PATIENTDEPARTMENTID  DIAGNOSIS1  \
# 0                           0            10                   10   410620009
# 1                           0            10                   10   410620009
# 2                           0            10                   10   410620009
#
# ...

# %%
from pathlib import Path

path = Path("../patients.csv")

print(path.resolve())
print(path.exists())
# Out:
# C:\Users\Bagdo\Documents\AirflowPractise\Patients_Enrollment\patients.csv
# True

# %%
check = pd.read_csv(path)

# %%
check
# Out:
#                                         Id   BIRTHDATE DEATHDATE          SSN  \
# 0     b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85  2019-02-17       NaN  999-65-3251
# 1     c1f1fcaa-82fd-d5b7-3544-c8f9708b06a8  2005-07-04       NaN  999-49-3323
# 2     339144f8-50e1-633e-a013-f361391c4cff  1998-05-11       NaN  999-10-8743
# 3     d488232e-bf14-4bed-08c0-a82f34b6a197  2003-01-28       NaN  999-56-6057
# 4     217f95a3-4e10-bd5d-fb67-0cfb5e8ba075  1993-12-23       NaN  999-91-4320
# ...                                    ...         ...       ...          ...
# 1158  409330fa-7ffd-dbfb-4eba-2349d58a6324  1979-02-28       NaN  999-68-5445
# 1159  cb328021-a854-dc94-e7ae-426580477308  1964-05-31       NaN  999-10-6445
# 1160  41862157-5c14-f706-4a94-d2929be969e7  1967-07-12       NaN  999-63-2407
# 1161  d53c57a5-4480-2481-32ee-b2844a991c9d  1948-07-28       NaN  999-37-8036
# 1162  cb1b2c74-d1c5-997c-6f8b-20ca9f332eef  1958-11-07       NaN  999-17-1411
#
# ...
